# %% [markdown]
# https://python.langchain.com/v0.2/docs/integrations/vectorstores/faiss/#manage-vector-store
# 이 내용에 대한 실습

# %%
import sys
import os

# 'app' 폴더가 있는 상위 경로를 sys.path에 추가
sys.path.append(os.path.abspath(".."))  # 현재 폴더의 상위 폴더를 추가

from app.vectordb.faiss_vectordb import FaissVectorDB

faissVectorDB = FaissVectorDB()

# %%
import uuid  # 청크 ID를 생성하기 위해 사용
from uuid import uuid4
from langchain_core.documents import Document


document_1 = Document(
    page_content="I had chocalate chip pancakes and scrambled eggs for breakfast this morning.",
    metadata={"source": "tweet"},
)

document_2 = Document(
    page_content="The weather forecast for tomorrow is cloudy and overcast, with a high of 62 degrees.",
    metadata={"source": "news"},
)

document_3 = Document(
    page_content="Building an exciting new project with LangChain - come check it out!",
    metadata={"source": "tweet"},
)

document_4 = Document(
    page_content="Robbers broke into the city bank and stole $1 million in cash.",
    metadata={"source": "news"},
)

document_5 = Document(
    page_content="Wow! That was an amazing movie. I can't wait to see it again.",
    metadata={"source": "tweet"},
)

document_6 = Document(
    page_content="Is the new iPhone worth the price? Read this review to find out.",
    metadata={"source": "website"},
)

document_7 = Document(
    page_content="The top 10 soccer players in the world right now.",
    metadata={"source": "website"},
)

document_8 = Document(
    page_content="LangGraph is the best framework for building stateful, agentic applications!",
    metadata={"source": "tweet"},
)

document_9 = Document(
    page_content="The stock market is down 500 points today due to fears of a recession.",
    metadata={"source": "news"},
)

document_10 = Document(
    page_content="I have a bad feeling I am going to get deleted :(",
    metadata={"source": "tweet"},
)

faissVectorDB.add_document_to_store(1, content="I had chocalate chip pancakes and scrambled eggs for breakfast this morning.", metadata={"source": "tweet"})

# documents = [
#     document_1,
#     document_2,
#     document_3,
#     document_4,
#     document_5,
#     document_6,
#     document_7,
#     document_8,
#     document_9,
#     document_10,
# ]
# uuids = [str(uuid4()) for _ in range(len(documents))]

# vector_store.add_documents(documents=documents, ids=uuids)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/engine/base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/engine/base.py:3300, in Engine.raw_connection(self)
#    3279 """Return a "raw" DBAPI connection from the connection pool.
#    3280
#    3281 The returned object is a proxied version of the DBAPI
#    (...)
#    3298
#    3299 """
# -> 3300 return self.pool.connect()
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/pool/base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
#     444 The connection is instrumented such that when its
#    (...)
#     447
#     448 """
# --> 449 return _ConnectionFairy._checkout(self)
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/pool/base.py:1263, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1262 if not fairy:
# -> 1263     fairy = _ConnectionRecord.checkout(pool)
#    1265     if threadconns is not None:
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/pool/base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/pool/impl.py:179, in QueuePool._do_get(self)
#     178 except:
# --> 179     with util.safe_reraise():
#     180         self._dec_overflow()
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/pool/impl.py:177, in QueuePool._do_get(self)
#     176 try:
# --> 177     return self._create_connection()
#     178 except:
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/pool/base.py:390, in Pool._create_connection(self)
#     388 """Called by subclasses to create a new ConnectionRecord."""
# --> 390 return _ConnectionRecord(self)
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/pool/base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/pool/base.py:900, in _ConnectionRecord.__connect(self)
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/pool/base.py:896, in _ConnectionRecord.__connect(self)
#     895 self.starttime = time.time()
# --> 896 self.dbapi_connection = connection = pool._invoke_creator(self)
#     897 pool.logger.debug("Created new connection %r", connection)
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/engine/create.py:643, in create_engine.<locals>.connect(connection_record)
#     641             return connection
# --> 643 return dialect.connect(*cargs, **cparams)
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/engine/default.py:620, in DefaultDialect.connect(self, *cargs, **cparams)
#     618 def connect(self, *cargs, **cparams):
#     619     # inherits the docstring from interfaces.Dialect.connect
# --> 620     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#
# OperationalError: could not translate host name "rag_server-db-1" to address: nodename nor servname provided, or not known
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[2], line 56
#      46 document_9 = Document(
#      47     page_content="The stock market is down 500 points today due to fears of a recession.",
#      48     metadata={"source": "news"},
#      49 )
#      51 document_10 = Document(
#      52     page_content="I have a bad feeling I am going to get deleted :(",
#      53     metadata={"source": "tweet"},
#      54 )
# ---> 56 faissVectorDB.add_document_to_store(1, content="I had chocalate chip pancakes and scrambled eggs for breakfast this morning.", metadata={"source": "tweet"})
#      58 # documents = [
#      59 #     document_1,
#      60 #     document_2,
#    (...)
#      71
#      72 # vector_store.add_documents(documents=documents, ids=uuids)
#
# File ~/project/langchain/rag_server/app/vectordb/faiss_vectordb.py:95, in FaissVectorDB.add_document_to_store(self, document_id, content, metadata)
#      92 self.vector_store.index.add(embedding_content)
#      94 # PostgreSQL docstore에 문서 추가
# ---> 95 self.vector_store.docstore.add_document(document_id, content, metadata)
#      97 # 인덱스와 문서 매핑 정보 저장
#      98 self.vector_store.index_to_docstore_id[document_id] = document_id
#
# File ~/project/langchain/rag_server/app/vectordb/faiss_vectordb.py:27, in PostgresDocstore.add_document(self, document_id, content, metadata)
#      21 new_document = OrgRSrcData(
#      22     org_resrc_id=document_id,
#      23     content=content,
#      24     document_metadata=metadata
#      25 )
#      26 self.session.add(new_document)
# ---> 27 self.session.commit()
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/orm/session.py:2017, in Session.commit(self)
#    2014 if trans is None:
#    2015     trans = self._autobegin_t()
# -> 2017 trans.commit(_to_root=True)
#
# File <string>:2, in commit(self, _to_root)
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/orm/state_changes.py:139, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     137 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     138 try:
# --> 139     ret_value = fn(self, *arg, **kw)
#     140 except:
#     141     raise
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/orm/session.py:1302, in SessionTransaction.commit(self, _to_root)
#    1300 if self._state is not SessionTransactionState.PREPARED:
#    1301     with self._expect_state(SessionTransactionState.PREPARED):
# -> 1302         self._prepare_impl()
#    1304 if self._parent is None or self.nested:
#    1305     for conn, trans, should_commit, autoclose in set(
#    1306         self._connections.values()
#    1307     ):
#
# File <string>:2, in _prepare_impl(self)
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/orm/state_changes.py:139, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     137 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     138 try:
# --> 139     ret_value = fn(self, *arg, **kw)
#     140 except:
#     141     raise
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/orm/session.py:1277, in SessionTransaction._prepare_impl(self)
#    1275     if self.session._is_clean():
#    1276         break
# -> 1277     self.session.flush()
#    1278 else:
#    1279     raise exc.FlushError(
#    1280         "Over 100 subsequent flushes have occurred within "
#    1281         "session.commit() - is an after_flush() hook "
#    1282         "creating new objects?"
#    1283     )
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/orm/session.py:4341, in Session.flush(self, objects)
#    4339 try:
#    4340     self._flushing = True
# -> 4341     self._flush(objects)
#    4342 finally:
#    4343     self._flushing = False
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/orm/session.py:4476, in Session._flush(self, objects)
#    4473     transaction.commit()
#    4475 except:
# -> 4476     with util.safe_reraise():
#    4477         transaction.rollback(_capture_exception=True)
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/orm/session.py:4437, in Session._flush(self, objects)
#    4435 self._warn_on_events = True
#    4436 try:
# -> 4437     flush_context.execute()
#    4438 finally:
#    4439     self._warn_on_events = False
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/orm/unitofwork.py:466, in UOWTransaction.execute(self)
#     464 else:
#     465     for rec in topological.sort(self.dependencies, postsort_actions):
# --> 466         rec.execute(self)
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/orm/unitofwork.py:642, in SaveUpdateAll.execute(self, uow)
#     640 @util.preload_module("sqlalchemy.orm.persistence")
#     641 def execute(self, uow):
# --> 642     util.preloaded.orm_persistence.save_obj(
#     643         self.mapper,
#     644         uow.states_for_mapper_hierarchy(self.mapper, False, False),
#     645         uow,
#     646     )
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/orm/persistence.py:60, in save_obj(base_mapper, states, uowtransaction, single)
#      57 states_to_update = []
#      58 states_to_insert = []
# ---> 60 for (
#      61     state,
#      62     dict_,
#      63     mapper,
#      64     connection,
#      65     has_identity,
#      66     row_switch,
#      67     update_version_id,
#      68 ) in _organize_states_for_save(base_mapper, states, uowtransaction):
#      69     if has_identity or row_switch:
#      70         states_to_update.append(
#      71             (state, dict_, mapper, connection, update_version_id)
#      72         )
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/orm/persistence.py:223, in _organize_states_for_save(base_mapper, states, uowtransaction)
#     211 def _organize_states_for_save(base_mapper, states, uowtransaction):
#     212     """Make an initial pass across a set of states for INSERT or
#     213     UPDATE.
#     214
#    (...)
#     220
#     221     """
# --> 223     for state, dict_, mapper, connection in _connections_for_states(
#     224         base_mapper, uowtransaction, states
#     225     ):
#     226         has_identity = bool(state.key)
#     228         instance_key = state.key or mapper._identity_key_from_state(state)
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/orm/persistence.py:1753, in _connections_for_states(base_mapper, uowtransaction, states)
#    1751     connection_callable = uowtransaction.session.connection_callable
#    1752 else:
# -> 1753     connection = uowtransaction.transaction.connection(base_mapper)
#    1754     connection_callable = None
#    1756 for state in _sort_states(base_mapper, states):
#
# File <string>:2, in connection(self, bindkey, execution_options, **kwargs)
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/orm/state_changes.py:139, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     137 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     138 try:
# --> 139     ret_value = fn(self, *arg, **kw)
#     140 except:
#     141     raise
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/orm/session.py:1039, in SessionTransaction.connection(self, bindkey, execution_options, **kwargs)
#    1029 @_StateChange.declare_states(
#    1030     (SessionTransactionState.ACTIVE,), _StateChangeStates.NO_CHANGE
#    1031 )
#    (...)
#    1036     **kwargs: Any,
#    1037 ) -> Connection:
#    1038     bind = self.session.get_bind(bindkey, **kwargs)
# -> 1039     return self._connection_for_bind(bind, execution_options)
#
# File <string>:2, in _connection_for_bind(self, bind, execution_options)
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/orm/state_changes.py:139, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     137 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     138 try:
# --> 139     ret_value = fn(self, *arg, **kw)
#     140 except:
#     141     raise
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/orm/session.py:1175, in SessionTransaction._connection_for_bind(self, bind, execution_options)
#    1173 try:
#    1174     if self._parent:
# -> 1175         conn = self._parent._connection_for_bind(
#    1176             bind, execution_options
#    1177         )
#    1178         if not self.nested:
#    1179             return conn
#
# File <string>:2, in _connection_for_bind(self, bind, execution_options)
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/orm/state_changes.py:139, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     137 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     138 try:
# --> 139     ret_value = fn(self, *arg, **kw)
#     140 except:
#     141     raise
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/orm/session.py:1189, in SessionTransaction._connection_for_bind(self, bind, execution_options)
#    1184             raise sa_exc.InvalidRequestError(
#    1185                 "Session already has a Connection associated "
#    1186                 "for the given Connection's Engine"
#    1187             )
#    1188     else:
# -> 1189         conn = bind.connect()
#    1190         local_connect = True
#    1192 try:
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/engine/base.py:3276, in Engine.connect(self)
#    3253 def connect(self) -> Connection:
#    3254     """Return a new :class:`_engine.Connection` object.
#    3255
#    3256     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3273
#    3274     """
# -> 3276     return self._connection_cls(self)
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/engine/base.py:148, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     146         self._dbapi_connection = engine.raw_connection()
#     147     except dialect.loaded_dbapi.Error as err:
# --> 148         Connection._handle_dbapi_exception_noconnection(
#     149             err, dialect, engine
#     150         )
#     151         raise
#     152 else:
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/engine/base.py:2440, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2438 elif should_wrap:
#    2439     assert sqlalchemy_exception is not None
# -> 2440     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2441 else:
#    2442     assert exc_info[1] is not None
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/engine/base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 if connection is None:
#     145     try:
# --> 146         self._dbapi_connection = engine.raw_connection()
#     147     except dialect.loaded_dbapi.Error as err:
#     148         Connection._handle_dbapi_exception_noconnection(
#     149             err, dialect, engine
#     150         )
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/engine/base.py:3300, in Engine.raw_connection(self)
#    3278 def raw_connection(self) -> PoolProxiedConnection:
#    3279     """Return a "raw" DBAPI connection from the connection pool.
#    3280
#    3281     The returned object is a proxied version of the DBAPI
#    (...)
#    3298
#    3299     """
# -> 3300     return self.pool.connect()
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/pool/base.py:449, in Pool.connect(self)
#     441 def connect(self) -> PoolProxiedConnection:
#     442     """Return a DBAPI connection from the pool.
#     443
#     444     The connection is instrumented such that when its
#    (...)
#     447
#     448     """
# --> 449     return _ConnectionFairy._checkout(self)
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/pool/base.py:1263, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1255 @classmethod
#    1256 def _checkout(
#    1257     cls,
#    (...)
#    1260     fairy: Optional[_ConnectionFairy] = None,
#    1261 ) -> _ConnectionFairy:
#    1262     if not fairy:
# -> 1263         fairy = _ConnectionRecord.checkout(pool)
#    1265         if threadconns is not None:
#    1266             threadconns.current = weakref.ref(fairy)
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/pool/base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     710     rec = cast(_ConnectionRecord, pool._do_get())
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#     715     dbapi_connection = rec.get_connection()
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/pool/impl.py:179, in QueuePool._do_get(self)
#     177     return self._create_connection()
#     178 except:
# --> 179     with util.safe_reraise():
#     180         self._dec_overflow()
#     181     raise
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/pool/impl.py:177, in QueuePool._do_get(self)
#     175 if self._inc_overflow():
#     176     try:
# --> 177         return self._create_connection()
#     178     except:
#     179         with util.safe_reraise():
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/pool/base.py:390, in Pool._create_connection(self)
#     387 def _create_connection(self) -> ConnectionPoolEntry:
#     388     """Called by subclasses to create a new ConnectionRecord."""
# --> 390     return _ConnectionRecord(self)
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/pool/base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     672 self.__pool = pool
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/pool/base.py:900, in _ConnectionRecord.__connect(self)
#     898     self.fresh = True
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#     902 else:
#     903     # in SQLAlchemy 1.4 the first_connect event is not used by
#     904     # the engine, so this will usually not be set
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/pool/base.py:896, in _ConnectionRecord.__connect(self)
#     894 try:
#     895     self.starttime = time.time()
# --> 896     self.dbapi_connection = connection = pool._invoke_creator(self)
#     897     pool.logger.debug("Created new connection %r", connection)
#     898     self.fresh = True
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/engine/create.py:643, in create_engine.<locals>.connect(connection_record)
#     640         if connection is not None:
#     641             return connection
# --> 643 return dialect.connect(*cargs, **cparams)
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/sqlalchemy/engine/default.py:620, in DefaultDialect.connect(self, *cargs, **cparams)
#     618 def connect(self, *cargs, **cparams):
#     619     # inherits the docstring from interfaces.Dialect.connect
# --> 620     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~/anaconda3/envs/ragserver/lib/python3.12/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) could not translate host name "rag_server-db-1" to address: nodename nor servname provided, or not known
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
